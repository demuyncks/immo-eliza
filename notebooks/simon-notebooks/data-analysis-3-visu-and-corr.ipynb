# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Load csv as df
path="../../data/simon-data/properties-2b-located.csv"
properties=pd.read_csv(path,index_col=0)
pd.set_option('display.max_columns',None)

# Correct types and index
properties[['Number of rooms','Fully equipped kitchen','Number of facades','State of the building']]=properties[['Number of rooms','Fully equipped kitchen','Number of facades','State of the building']].astype(int)
properties=properties.drop('index',axis=1)

# %%
# Visualization
## Distributions - Prices (kde) - Type and subtype (hist) - Type of sale (pie) - Living Area (kde) - State of building (hist)
fig, axes = plt.subplots(4, 1, figsize=(10, 20))
sns.kdeplot(properties['Price'],ax=axes[0])
sns.countplot(data=properties,x="Type of property",hue="Subtype of property",ax=axes[1])
sns.histplot(properties['Living Area'],ax=axes[2])
sns.countplot(data=properties,x='Region',hue='State of the building',ax=axes[3])
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
properties.columns
properties.dtypes
# Out:
# URL                           str
# Zip code                    int64
# City                          str
# Type of property              str
# Subtype of property           str
# Price                       int64
# Type of sale                  str
# Number of rooms             int64
# Living Area                 int64
# Fully equipped kitchen      int64
# Furnished                   int64
# Open fire                   int64
# Terrace                     int64
# Garden                      int64
# Garden area               float64
# Surface of the land       float64
# Number of facades           int64
# Swimming pool               int64
# State of the building       int64
# Province                      str
# Region                        str
# dtype: object

# %%
## Correlations
### Each criteria on the price (only int and float)
properties[['Price','Number of rooms']].corr()

## Geo (price map by region and province)
# Out:
#                     Price  Number of rooms
# Price            1.000000         0.422025
# Number of rooms  0.422025         1.000000

# %%
properties
# Out:
#                                                      URL  Zip code  \
# 0      https://immovlan.be/en/detail/residence/for-sa...      2200
# 1      https://immovlan.be/en/detail/apartment/for-sa...      1190
# 2      https://immovlan.be/en/detail/residence/for-sa...      7100
# 3      https://immovlan.be/en/detail/residence/for-sa...      2160
# 4      https://immovlan.be/en/detail/residence/for-sa...      6660
# ...                                                  ...       ...
# 11808  https://immovlan.be/en/detail/apartment/for-sa...      1090
# 11809  https://immovlan.be/en/detail/residence/for-sa...      9190
# 11810  https://immovlan.be/en/detail/apartment/for-sa...      1030
# 11811  https://immovlan.be/en/detail/residence/for-sa...      6470
# 11812  https://immovlan.be/en/detail/residence/for-sa...      1200
#
#                          City Type of property Subtype of property    Price  \
# 0                   Herentals            House           residence   369000
# 1                       Vorst        Apartment           apartment   385000
# 2                 La Louvière            House           residence   135000
# 3                   Wommelgem            House           residence   284000
# 4                  Houffalize            House           residence   299000
# ...                       ...              ...                 ...      ...
# 11808                   Jette        Apartment           apartment   410000
# 11809                 Stekene            House           residence   450000
# 11810              Schaarbeek        Apartment           apartment   229000
# 11811                  Sautin            House           residence   199000
# 11812  Sint-Lambrechts-Woluwe            House           residence  1090000
#
#       Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 0         for sale                3          378                       2
# 1         for sale                2          100                       2
# 2         for sale                3          125                       1
# 3         for sale                3          180                       2
# 4         for sale                4          124                       3
# ...            ...              ...          ...                     ...
# 11808     for sale                4          197                       2
# 11809     for sale                3          170                       2
# 11810     for sale                1           72                       1
# 11811     for sale                3          134                       2
# 11812     for sale                5          243                       2
#
#        Furnished  Open fire  Terrace  Garden  Garden area  \
# 0              0          0        1       1        255.0
# 1              0          0        1       0          0.0
# 2              0          0        0       1        255.0
# 3              0          0        0       1        240.0
# 4              0          0        1       1        255.0
# ...          ...        ...      ...     ...          ...
# 11808          0          0        1       0          0.0
# 11809          0          0        0       1        255.0
# 11810          0          0        0       0          0.0
# 11811          0          1        1       1        255.0
# 11812          0          0        1       1        255.0
#
#        Surface of the land  Number of facades  Swimming pool  \
# 0                    300.0                  2              0
# 1                    649.0                  3              0
# 2                    649.0                  2              0
# 3                    295.0                  2              0
# 4                    441.0                  3              0
# ...                    ...                ...            ...
# 11808                649.0                  3              0
# 11809                300.0                  3              0
# 11810                649.0                  3              0
# 11811               1497.0                  3              0
# 11812                237.0                  2              0
#
#        State of the building       Province          Region
# 0                          0        Antwerp  Flemish Region
# 1                          2       Brussels        Brussels
# 2                          2        Hainaut  Walloon Region
# 3                          0        Antwerp  Flemish Region
# 4                          4        Hainaut  Walloon Region
# ...                      ...            ...             ...
# 11808                      0       Brussels        Brussels
# 11809                      4  East Flanders  Flemish Region
# 11810                      1       Brussels        Brussels
# 11811                      2        Hainaut  Walloon Region
# 11812                      1       Brussels        Brussels
#
# [11813 rows x 21 columns]
